# %%
import imagej
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# initialize ImageJ
ij = imagej.init('sc.fiji:fiji:2.14.0') 
print(f"ImageJ version: {ij.getVersion()}")

# %%
def area_fraction(arr): #Returns area fraction of a binary array

    return np.sum(arr > 0) / arr.size

# %%
path = r"C:\Users\magfa\Documents\Prosjekt\Prosjektbilder\1m_x100 (11).tif"

# %%
imp = ij.IJ.openImage(path)

np_arr = np.asarray(ij.py.from_java(imp))

print(area_fraction(np_arr))
# Out:
# Operating in headless mode - the original ImageJ will have limited functionality.
# Operating in headless mode - the IJ class will not be fully functional.
# 0.012735902583798883

# %%
import pandas as pd
def area_fractions_from_folder(folder_path, csv):
    results = []
    folder = Path(folder_path)

    for file in folder.iterdir():
        imp = ij.IJ.openImage(str(file.resolve()))
        arr = np.asarray(ij.py.from_java(imp))
        imp.close()
        results.append({f"Filename: {file.stem}", area_fraction(arr)})

    df = pd.DataFrame(results)
    avg = df.iloc[:, 1].mean()
    df.to_csv(csv, index=False)
    print(avg)

# %%
area_fractions_from_folder(r"C:\Users\magfa\Documents\Prosjekt\Prosjektbilder\resultat_1m\x100" ,r"C:\Users\magfa\Documents\Prosjekt\Prosjektbilder\resultat_1m\1m_x100.csv")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11520\1707957767.py in <cell line: 1>()
# ----> 1 area_fractions_from_folder(r"C:\Users\magfa\Documents\Prosjekt\Prosjektbilder\resultat_1m\x100" ,r"C:\Users\magfa\Documents\Prosjekt\Prosjektbilder\resultat_1m\1m_x100.csv")
#
# ~\AppData\Local\Temp\ipykernel_11520\1862405598.py in area_fractions_from_folder(folder_path, csv)
#      11
#      12     df = pd.DataFrame(results)
# ---> 13     avg = df.iloc[:, 1].mean()
#      14     df.to_csv(csv, index=False)
#      15     print(avg)
#
# c:\Users\magfa\anaconda3\envs\ml-env\lib\site-packages\pandas\core\series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6547         **kwargs,
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#    6551     @doc(make_doc("median", ndim=1))
#
# c:\Users\magfa\anaconda3\envs\ml-env\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# c:\Users\magfa\anaconda3\envs\ml-env\lib\site-packages\pandas\core\generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   12376
# > 12377         return self._reduce(
#   12378             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379         )
#
# c:\Users\magfa\anaconda3\envs\ml-env\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6455                     "with non-numeric dtypes."
#    6456                 )
# -> 6457             return op(delegate, skipna=skipna, **kwds)
#    6458
#    6459     @Appender(make_doc("any", ndim=1))
#
# c:\Users\magfa\anaconda3\envs\ml-env\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     145                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#     149             return result
#
# c:\Users\magfa\anaconda3\envs\ml-env\lib\site-packages\pandas\core\nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     402             mask = isna(values)
#     403
# --> 404         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     405
#     406         if datetimelike:
#
# c:\Users\magfa\anaconda3\envs\ml-env\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     717
#     718     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 719     the_sum = values.sum(axis, dtype=dtype_sum)
#     720     the_sum = _ensure_numeric(the_sum)
#     721
#
# c:\Users\magfa\anaconda3\envs\ml-env\lib\site-packages\numpy\_core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      50 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      51          initial=_NoValue, where=True):
# ---> 52     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      53
#      54 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: can only concatenate str (not "numpy.float64") to str
